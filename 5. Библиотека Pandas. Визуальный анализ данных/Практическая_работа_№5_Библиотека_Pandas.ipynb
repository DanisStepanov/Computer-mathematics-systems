# %% [markdown]
# <a href="https://colab.research.google.com/github/DanisStepanov/Computer-mathematics-systems/blob/main/5.%20%D0%91%D0%B8%D0%B1%D0%BB%D0%B8%D0%BE%D1%82%D0%B5%D0%BA%D0%B0%20Pandas.%20%D0%92%D0%B8%D0%B7%D1%83%D0%B0%D0%BB%D1%8C%D0%BD%D1%8B%D0%B9%20%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%965_%D0%91%D0%B8%D0%B1%D0%BB%D0%B8%D0%BE%D1%82%D0%B5%D0%BA%D0%B0_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практическая работа №5. Библиотека Pandas. Визуальный анализ данных

# %% [markdown]
# ## Комплексное задание №1. Применение основных методов для анализа данных
#
# 1. Скачайте этот блокнот к себе.
# 2. Заполните пропущенные ячейки, отвечая на заданные вопросы. Там должен быть код! (если не сказано обратное)
# 3. Сохраните результат в своём гитхаб репозитории.
#
# #### Полезная литература
# - [**Блокнот с теорией**](https://colab.research.google.com/drive/1SLqmaYz4xEsxVV-LGwb3ityheBTzHJQu?usp=sharing)
# - http://pandas.pydata.org/pandas-docs/stable/10min.html
# - https://pandas.pydata.org/pandas-docs/stable/indexing.html
# - https://pandas.pydata.org/pandas-docs/stable/missing_data.html

# %% [markdown]
# В этом задании мы с Вами рассмотрим датасет [Adult Data Set](https://archive.ics.uci.edu/ml/datasets/Adult).
# Основывается он на данных переписи населения 1994 года в США.
#
# Расшифровка содержимого колонок:
#
# - age: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous. sampling weight, more here: SIPP Weighting.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - sex: Female, Male.
# - capital-gain: continuous. Income from investment sources, apart from wages/salary.
# - capital-loss: continuous. Losses from investment sources, apart from wages/salary.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %% [markdown]
# возраст: постоянный.
#
# класс работы: Частная, Самозанятая, Федеральное правительство, местное правительство, правительство штата, Без оплаты, Никогда не работала.
#
# тип работы: постоянная. вес для отбора проб, подробнее здесь: Взвешивание SIPP.
# образование: Бакалавры, Некоторые-колледжи, 11-е, высшее, Профессиональная школа, доценты acdm, доценты voc, 9-е, 7-8-е, 12-е, магистратура, 1-4-е, 10-е, докторантура, 5-6-е, Дошкольное образование.
#
# образование-количество: непрерывное.
#
# семейное положение: Женат (гражданская супруга), Разведен (а), Никогда не был женат(а), Живет раздельно (а), Вдовец(а), Супруг(а) отсутствует(а), Женат(а) после(а) брака.
#
# профессия: Техническая поддержка, Ремонт оборудования, Прочие услуги, Продажи, Руководитель-менеджер, Профессиональная специальность, Уборщики-разнорабочие, Машинный инспектор, Администратор-клерк, Сельское хозяйство-рыболовство, Транспортные перевозки, Частный дом, Охрана, Вооруженные силы.
#
# тип отношений: Жена, Собственный ребенок, Муж, Не состоит в семье, Другие родственники, Не женат.
#
# раса: Белые, Азиаты, Выходцы с тихоокеанских островов, Американские индейцы, эскимосы, Другие, Черные.
#
# пол: Женщина, Мужчина.
#
# прирост капитала: постоянный. Доходы от инвестиционных источников, помимо заработной платы.
#
# потери капитала: постоянные. Потери от источников инвестиций, за исключением заработной платы.
#
# количество часов в неделю: постоянное.
#
# страна происхождения: Соединенные Штаты, Камбоджа, Англия, Пуэрто-Рико, Канада, Германия, отдаленные районы США (Гуам, США и т.д.), Индия, Япония, Греция, Южная Корея, Китай, Куба, Иран, Гондурас, Филиппины, Италия, Польша, Ямайка, Вьетнам, Мексика, Португалия, Ирландия, Франция, Доминиканская Республика, Лаос, Эквадор, Тайвань, Гаити, Колумбия, Венгрия, Гватемала, Никарагуа, Шотландия, Таиланд, Югославия, Сальвадор, Тринадад и Тобаго, Перу, Гонконг, Голландия, Нидерланды.

# %%
# %matplotlib inline
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# Если вы увидели warning, не переживайте, всё хорошо.
# - https://stackoverflow.com/questions/40845304/runtimewarning-numpy-dtype-size-changed-may-indicate-binary-incompatibility
# - https://github.com/numpy/numpy/pull/432

# %%
columns='age,workclass,fnlwgt,education,education.num,marital.status,occupation,relationship,race,sex,capital.gain,capital.loss,hours.per.week,native.country,income'.split(',')
# df = pd.read_csv('../../data/adult.csv.gz', na_values='?') # можно загрузить из файла или URL
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', na_values=' ?', names=columns)
df.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital.status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital.gain  capital.loss  hours.per.week  native.country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %% [markdown]
# 1) Выведите последние 10 элеметнов датасета

# %%
df.tail(10)
# Out:
#        age      workclass  fnlwgt      education  education.num  \
# 32551   32        Private   34066           10th              6
# 32552   43        Private   84661      Assoc-voc             11
# 32553   32        Private  116138        Masters             14
# 32554   53        Private  321865        Masters             14
# 32555   22        Private  310152   Some-college             10
# 32556   27        Private  257302     Assoc-acdm             12
# 32557   40        Private  154374        HS-grad              9
# 32558   58        Private  151910        HS-grad              9
# 32559   22        Private  201490        HS-grad              9
# 32560   52   Self-emp-inc  287927        HS-grad              9
#
#             marital.status          occupation    relationship  \
# 32551   Married-civ-spouse   Handlers-cleaners         Husband
# 32552   Married-civ-spouse               Sales         Husband
# 32553        Never-married        Tech-support   Not-in-family
# 32554   Married-civ-spouse     Exec-managerial         Husband
# 32555        Never-married     Protective-serv   Not-in-family
# 32556   Married-civ-spouse        Tech-support            Wife
# 32557   Married-civ-spouse   Machine-op-inspct         Husband
# 32558              Widowed        Adm-clerical       Unmarried
# 32559        Never-married        Adm-clerical       Own-child
# 32560   Married-civ-spouse     Exec-managerial            Wife
#
#                       race      sex  capital.gain  capital.loss  \
# 32551   Amer-Indian-Eskimo     Male             0             0
# 32552                White     Male             0             0
# 32553   Asian-Pac-Islander     Male             0             0
# 32554                White     Male             0             0
# 32555                White     Male             0             0
# 32556                White   Female             0             0
# 32557                White     Male             0             0
# 32558                White   Female             0             0
# 32559                White     Male             0             0
# 32560                White   Female         15024             0
#
#        hours.per.week  native.country  income
# 32551              40   United-States   <=50K
# 32552              45   United-States   <=50K
# 32553              11          Taiwan   <=50K
# 32554              40   United-States    >50K
# 32555              40   United-States   <=50K
# 32556              38   United-States   <=50K
# 32557              40   United-States    >50K
# 32558              40   United-States   <=50K
# 32559              20   United-States   <=50K
# 32560              40   United-States    >50K

# %% [markdown]
# 2) Сколько колонок и сколько строк в этом датасете?

# %%
df.shape
# Out:
# (32561, 15)

# %% [markdown]
# 3) Какие типы данных у элементов этого датасета?

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %% [markdown]
# 4) Какие признаки имеют пропуски?

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %% [markdown]
# 5) Как вы думаете, с чем связаны пропуски этих значение. Напишите развернутый ответ в ячейке ниже.

# %% [markdown]
# Ваш ответ: Первое что приходит на ум, это ошибка в заполнение данных. То есть из-за невнимательности заполняющего опросник. Второе что приходит на ум, безработные люди постыдились отвечать и решили пропустить этот вопрос, либо же они занимаются чем-то нелигальным.
# А native.country там пропуски могут быть, потому что это могли быть сираоты и могут не знать своего места происхождения, либо же беженцы, ну или аналогично, могут специально скрывать своё происхождение.

# %% [markdown]
# 6) Какие и сколько различных рабочих классов workclass представлено в выборке?

# %%
print(df['workclass'].unique())
print(df['workclass'].nunique())
# Out:
# [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  nan ' Self-emp-inc' ' Without-pay' ' Never-worked']
# 8

# %% [markdown]
# 7) Какой средний возраст женщин и мужчин?

# %%
df.groupby('sex')['age'].mean()
# Out:
# sex
# Female    36.858230
# Male      39.433547
# Name: age, dtype: float64

# %% [markdown]
# 8) Постройте гистограмму(bar) распределения образования людей (education)

# %%
df['education'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='education'>

# %% [markdown]
# 9) Каковы средние значения и среднеквадратичные отклонения возраста тех, кто получает более 50K в год (признак income) и тех, кто получает менее 50K в год?

# %%
df.groupby('income')['age'].agg(['mean', 'std'])
# Out:
#              mean        std
# income
# <=50K   36.783738  14.020088
# >50K    44.249841  10.519028

# %% [markdown]
# 10) Правда ли, что люди, которые получают больше 50k, имеют как минимум высшее образование? (признак education - Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters или Doctorate)

# %% [markdown]
# 11) Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак marital-status)? Женатыми считаем тех, у кого marital-status начинается с Married (Married-civ-spouse, Married-spouse-absent или Married-AF-spouse), остальных считаем холостыми.

# %%
mujiki = df[df['sex'].str.strip() == 'Male'].copy()
mujiki['is_married'] = mujiki['marital.status'].str.strip().str.startswith('Married')
result = mujiki.groupby('is_married')['income'].value_counts(normalize=True)
print(result)
# Out:
# is_married  income
# False       <=50K     0.915505
#             >50K      0.084495
# True        <=50K     0.559486
#             >50K      0.440514
# Name: proportion, dtype: float64

# %% [markdown]
# В true у нас женатые мужчины. Исходя из вывода программы можно сделать вывод, что женатые мужчины которые зарабатывают больше 50к их больше, чем тех кто холостяк.

# %% [markdown]
# 12) Постройте [сводную таблицу](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) для отображения зависимостей среднего времени работы (hours.per.week) с доходом (income) для каждой страны (native.country).
#
#
# > Пример фрагмента таблицы:
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
df.groupby(['native.country', 'income'])['hours.per.week'].mean().unstack()
# Out:
# income                          <=50K       >50K
# native.country
# Cambodia                    41.416667  40.000000
# Canada                      37.914634  45.641026
# China                       37.381818  38.900000
# Columbia                    38.684211  50.000000
# Cuba                        37.985714  42.440000
# Dominican-Republic          42.338235  47.000000
# Ecuador                     38.041667  48.750000
# El-Salvador                 36.030928  45.000000
# England                     40.483333  44.533333
# France                      41.058824  50.750000
# Germany                     39.139785  44.977273
# Greece                      41.809524  50.625000
# Guatemala                   39.360656  36.666667
# Haiti                       36.325000  42.750000
# Holand-Netherlands          40.000000        NaN
# Honduras                    34.333333  60.000000
# Hong                        39.142857  45.000000
# Hungary                     31.300000  50.000000
# India                       38.233333  46.475000
# Iran                        41.440000  47.500000
# Ireland                     40.947368  48.000000
# Italy                       39.625000  45.400000
# Jamaica                     38.239437  41.100000
# Japan                       41.000000  47.958333
# Laos                        40.375000  40.000000
# Mexico                      40.003279  46.575758
# Nicaragua                   36.093750  37.500000
# Outlying-US(Guam-USVI-etc)  41.857143        NaN
# Peru                        35.068966  40.000000
# Philippines                 38.065693  43.032787
# Poland                      38.166667  39.000000
# Portugal                    41.939394  41.500000
# Puerto-Rico                 38.470588  39.416667
# Scotland                    39.444444  46.666667
# South                       40.156250  51.437500
# Taiwan                      33.774194  46.800000
# Thailand                    42.866667  58.333333
# Trinadad&Tobago             37.058824  40.000000
# United-States               38.799127  45.505369
# Vietnam                     37.193548  39.200000
# Yugoslavia                  41.600000  49.500000

# %% [markdown]
# 13) Постройте сводную таблицу для сравнения уровня образования и разности между capital.gain и capital.loss по следующему алгоритму:&nbsp;
# 1. Создайте вспомогательную таблицу (датафрейм) и добавьте в неё столбец "education" из целевой таблицы
# 2. Добавьте во вспомогательную таблицу ещё один столбец "capital.diff", значиниями которого будут являться разности столбцов capital.gain и capital.loss целевой таблицы
# 3. Удалите во вспомогательной таблице все строки, в которых значение столбца "capital.diff" равно нулю
# &nbsp; Подсказка:
# ```
# summary_table = summary_table[summary_table['capital.diff'] != 0 ]
# ```
# 4. Для набора значений из столбца "capital.diff", необходимо сформировать 10 категорий (кластеров), это можно сделать с помощью математических функций, типа log, извлечение корня N-ой степени и округления, для последующего перехода к категориальным признакам.
#   * В нашем случае, можно воспользоваться методом [pd.qcut()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.qcut.html) и равномерно разделить наш набор данных на целевое количество категорий
# 5. Добавьте во вспомогательную таблицу столбец "categories", и проинициализируйте его значениями категорий, которые возвращает метод pd.qcut()
# &nbsp; Пример:
# ```
# summary_table['categories'] = pd.qcut(summary_table["capital.diff"], q = 10)
#
# 6. Постройте сводную таблицу с помощью метода pivot_table(),
#
# Примерная структура таблицы (в качестве значений выводится количество людей, относящихся к той или иной группе):
#
# ![image.png](data:image/png;base64,...)

# %%
summary_table = pd.DataFrame()
summary_table['education'] = df['education']
summary_table['capital.diff'] = df['capital.gain'] - df['capital.loss']
summary_table = summary_table[summary_table['capital.diff'] != 0]
summary_table['categories'] = pd.qcut(summary_table["capital.diff"], q=10)
res = summary_table.groupby(['education', 'categories'])['capital.diff'].count()
res
#не понятно, правильно или нет
# Out:
# /tmp/ipykernel_165/2107041474.py:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   res = summary_table.groupby(['education', 'categories'])['capital.diff'].count()
# education     categories
# 10th          (-4356.001, -1977.0]     11
#               (-1977.0, -1887.0]        4
#               (-1887.0, -1594.0]       10
#               (-1594.0, 2174.0]        13
#               (2174.0, 3137.0]         11
#                                      ...
# Some-college  (3137.0, 4787.0]         90
#               (4787.0, 7298.0]        104
#               (7298.0, 8614.0]         61
#               (8614.0, 15024.0]        65
#               (15024.0, 99999.0]       26
# Name: capital.diff, Length: 160, dtype: int64

# %% [markdown]
# 14) Женщины из каких стран получают в среднем большую зарплату (>50K) чаще.

# %%
women = df[df['sex'].str.strip() == 'Female'].copy()
women['bolsh_v_sred'] = (women['income'].str.strip() == '>50K').astype(int)
res = women.groupby('native.country')['bolsh_v_sred'].mean().sort_values(ascending=False)
res
# Out:
# native.country
# Yugoslavia                    0.333333
# Taiwan                        0.266667
# France                        0.250000
# Iran                          0.250000
# Japan                         0.250000
# Italy                         0.238095
# China                         0.238095
# Canada                        0.230769
# Greece                        0.200000
# Scotland                      0.200000
# England                       0.187500
# India                         0.181818
# Portugal                      0.166667
# Hong                          0.166667
# Hungary                       0.166667
# Philippines                   0.164384
# Honduras                      0.142857
# Ireland                       0.142857
# Laos                          0.125000
# Germany                       0.116667
# United-States                 0.110721
# Poland                        0.105263
# South                         0.100000
# Thailand                      0.090909
# Nicaragua                     0.083333
# Cuba                          0.075000
# Dominican-Republic            0.057143
# Haiti                         0.050000
# Vietnam                       0.043478
# Puerto-Rico                   0.038462
# El-Salvador                   0.028571
# Jamaica                       0.023256
# Mexico                        0.013699
# Ecuador                       0.000000
# Columbia                      0.000000
# Cambodia                      0.000000
# Holand-Netherlands            0.000000
# Guatemala                     0.000000
# Peru                          0.000000
# Outlying-US(Guam-USVI-etc)    0.000000
# Trinadad&Tobago               0.000000
# Name: bolsh_v_sred, dtype: float64

# %% [markdown]
# 15) Создайте случайную колонку - magic_salary, которую нужно будет вычислить следующим образом: если зарплата небольшая (<50K), тогда случайно выберите число из диапазона [0,50]. Если зарплата выше 50K тогда из диапазона [51, 200]. Посчитайте среднюю зарплату в час для групп людей с одни уровнем образования на основе нашей случайной колонки magic_salary

# %%
import numpy as np
def f(income_row):
    if income_row == '>50K':
        return np.random.randint(51, 201)
    else:
        return np.random.randint(0, 51)
df['magic_salary'] = df['income'].apply(f)
df['magic_salary_per_hour'] = df['magic_salary'] / df['hours.per.week']
res = df.groupby('education')['magic_salary_per_hour'].mean().sort_values(ascending=False)
print(res)
# Out:
# education
# 11th            1.025278
# 10th            0.897413
# 9th             0.854909
# 12th            0.853327
# 7th-8th         0.852291
# 1st-4th         0.825932
# Assoc-acdm      0.803599
# Preschool       0.802196
# Some-college    0.793764
# Doctorate       0.753706
# Assoc-voc       0.736079
# HS-grad         0.722284
# 5th-6th         0.710148
# Masters         0.698115
# Bachelors       0.688445
# Prof-school     0.644248
# Name: magic_salary_per_hour, dtype: float64

# %% [markdown]
# ## Комплексное задание №2. Визуальный анализ данных. Часть 1

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# В этом задании Вам предлагается провести визуальный анализ датасета о прокатах велосипедов https://www.kaggle.com/c/bike-sharing-demand/data. Оригинальная задача предполагает построение модели предсказания количества прокатов в городе в зависимости от погоды.

# %% [markdown]
# Для каждого дня проката известны следующие признаки (как они были указаны в источнике данных):
# - season: 1 - весна, 2 - лето, 3 - осень, 4 - зима
# - yr: 0 - 2011, 1 - 2012
# - mnth: от 1 до 12
# - holiday: 0 - нет праздника, 1 - есть праздник
# - weekday: от 0 до 6
# - workingday: 0 - нерабочий день, 1 - рабочий день
# - weathersit: оценка благоприятности погоды от 1 (чистый, ясный день) до 4 (ливень, туман)
# - temp: температура в Цельсиях
# - atemp: температура по ощущениям в Цельсиях
# - hum: влажность
# - windspeed(mph): скорость ветра в милях в час
# - windspeed(ms): скорость ветра в метрах в секунду
# - cnt: количество арендованных велосипедов (это целевой признак, его мы будем предсказывать)

# %% [markdown]
# Загрузите самостоятельно(!), с помощью pandas файл `bikes_rent.csv.gz` и выведите первые 5 строк. Ознакомьтесь с данными с помощью функций describe и info.

# %% [markdown]
# https://www.kaggle.com/datasets/yasserh/bike-sharing-dataset

# %%
df = pd.read_csv('./train.csv')
df.head(5)
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
df['datetime']=pd.to_datetime(df['datetime'])
df['month']=df['datetime'].dt.month

# %%
df['month'].head(4000)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3995    9
# 3996    9
# 3997    9
# 3998    9
# 3999    9
# Name: month, Length: 4000, dtype: int32

# %% [markdown]
# Давайте посмотрим на графиках, как целевой признак зависит количество прокатов (cnt) зависит от остальных признаков `df.columns[:-1]`.

# %%
cols_to_plot = df.select_dtypes(include=['number']).columns.drop('count')
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(20, 15))
for idx, feature in enumerate(cols_to_plot):
    sns.scatterplot(data=df, x=feature, y="count", ax=axes[idx // 4, idx % 4], alpha=0.3)
    axes[idx // 4, idx % 4]

# %% [markdown]
# ### 1. Ответьте на вопросы:
#
# #### Каков характер зависимости числа прокатов от месяца?

# %%
plt.figure(figsize=(10, 5))
sns.barplot(data=df, x='month', y='count')
plt.show()

# %% [markdown]
# ответ: Пик пользования велосипедами приходится на май-октябрь, видимо это связано с тем что дороги позволяют кататься на велосипедах.

# %% [markdown]
# #### Укажите один или два признака, от которых число прокатов скорее всего зависит линейно
# _(чем больше значение, тем больше прокатов или наоборот, например)_
#
# Можете проверить результат с помощью lnplot.

# %% [markdown]
# Ответ: casual,registered

# %% [markdown]
# ### 2. Корреляционная матрица
#
# Напомним, что корреляция отражает взаимосвязь двух случайных величин. Она бывает положительная и отрицательная. Чем ближе коэффициент корреляции к нулю, тем меньше взаимосвязь. Чем больше абсолютная корреляци, тем взаимосвязь больше.
#
# Постройте heatmap корреляционной матрицы. Матрица формируется средствами pandas, со стандартным значением параметров.

# %%
cor_mat = df.corr()
plt.figure(figsize=(18, 16))
sns.heatmap(cor_mat, annot=True)
plt.show()

# %% [markdown]
# **Ответьте на вопрос**: с какими признаками количество прокатов коррелирует меньше всего (около 4 штуки). А с какими больше всего?

# %% [markdown]
# С кем меньше всего корелирует: holiday, workingday,winspeed, weather
# \
# С кем больше всего: registered, casual, temp, atemp, humidity

# %% [markdown]
# ### 3. Barpot
#
# Постройте Bar-график суммарного количества прокатов велосипедов по месяцам за каждый год одновременно. (будет 24 столбика)

# %%
df['year'] = df['datetime'].dt.year
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  month  year
# 0        81        0.0       3          13     16      1  2011
# 1        80        0.0       8          32     40      1  2011
# 2        80        0.0       5          27     32      1  2011
# 3        75        0.0       3          10     13      1  2011
# 4        75        0.0       0           1      1      1  2011

# %%
mat = df.groupby(['year', 'month'])['count'].sum().reset_index()
plt.figure(figsize=(15, 7))
sns.barplot(data=mat, x='month', y='count', hue='year', palette='viridis')
plt.show()

# %% [markdown]
# **Ответьте на вопрос:** почему в предыдущем графике была такая большая корреляция между количеством прокатов и годом?

# %% [markdown]
# Ответ:Как предположение, произошёл рост компании. Можно посмотреть на registered у него корреляция с count 0,97. Что говорит, что количество зарегестрированных пользователей выросло.

# %% [markdown]
# ### 4. Countplot
#
# Постройте countplot диаграммы для признаков `weekday`, `weathersit`,

# %%
df['weekday'] = df['datetime'].dt.weekday
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))
sns.countplot(data=df, x='weekday', ax=axes[0], palette='viridis')
sns.countplot(data=df, x='weather', ax=axes[1], palette='viridis')
plt.show()
# Out:
# /tmp/ipykernel_343/875397043.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='weekday', ax=axes[0], palette='viridis')
# /tmp/ipykernel_343/875397043.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='weather', ax=axes[1], palette='viridis')

# %% [markdown]
# **Ответьте на вопрос:** что вы можете сказать о том, как формировался этот датасет.

# %% [markdown]
# Ответ: Про weekday можно сказать, что все столбики почти одинаковы то есть записи в систему делали каждый час. И видимо не особо важно было какой недели был.
# \
# Про weather можно сказать, что данные вполне реальны, поскольки самый большой столбец показывает, что люди чаще арендуют велосипеды в хорошую погоду, что звучит логично. Да и чаще хорошая погода, чем плохая(Для аренды велосипедов)

# %% [markdown]
# **Ответьте на вопрос:** как называется распределение значений признака `weekday`?

# %% [markdown]
#
# Ответ:равномерное распределение, либо мб дискретное равномерное распределение

# %% [markdown]
# ### 5. Распределение
#
# Постройте распределение целевого признака.

# %%
sns.histplot(df['count'], color='red')
plt.xlabel('Количество прокатов за час')
plt.ylabel('Частота (количество таких часов)')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# **Ответьте на вопрос:** основываясь на графике, сколько приблизительно в среднем прокатов бывает в день?

# %% [markdown]
# Ответ:Если на глаз, приблизительно 150-200 в час прокатов. Умножить на 24 то плюс минус 3600-4800 прокатов в день

# %% [markdown]
# ### 6. Совместное распределение признаков
#
# Постройте график совместного распределения признаков температура и ощущение температуры.

# %%
plt.figure(figsize=(10, 8))
plt.hexbin(df['temp'], df['atemp'], gridsize=30, cmap='YlOrRd')
plt.colorbar(label='Количество записей')
plt.xlabel('Температура (temp)')
plt.ylabel('Ощущаемая температура (atemp)')
plt.title('Плотность распределения temp vs atemp (Hexbin)')
plt.show()

# %%
error_rows = df[(df['temp'] > 25) & (df['atemp'] < 15)]
print(f"Найдено странных строк: {len(error_rows)}")
error_rows[['temp', 'atemp']].head()
# Out:
# Найдено странных строк: 24
#        temp  atemp
# 8991  27.88  12.12
# 8992  27.06  12.12
# 8993  27.06  12.12
# 8994  26.24  12.12
# 8995  26.24  12.12

# %%
error_indices = df[(df['temp'] > 25) & (df['atemp'] < 15)].index
plt.figure(figsize=(12, 7))
sns.scatterplot(data=df, x='temp', y='atemp', alpha=0.2, color='gray', label='Все данные')
plt.scatter(df.loc[error_indices, 'temp'],
            df.loc[error_indices, 'atemp'],
            color='red', s=100, edgecolors='black', label='Аномалии')
plt.title('Поиск аномалий: temp vs atemp', fontsize=15)
plt.xlabel('Реальная температура (temp)')
plt.ylabel('Ощущаемая температура (atemp)')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

plt.show()

# %% [markdown]
# **Ответьте на вопрос:** вас в этом графике ничего не настораживает? Почему?

# %% [markdown]
# Ответ:Сначала не понял, что нужно увидеть. Обратился к ИИ, он это увидел, на первом моём графике и только с её помощью, я понял о чём идёт речь. Есть анамальные значения при которых реальная температура соответствует 25-35 градусам, а ощущаемая темпреатура 12 градусов, нельзя объяснить почему.

# %% [markdown]
# ### 7. Боксплот (ящик с усами)
#
# Постройте график распределения (боксплот) количества прокатов велосипедов по месяцам в зависимости от того рабочий это день или нет.

# %%
sns.boxplot(data=df, x='month', y='count', hue='workingday', palette='Set2')
plt.xlabel('Месяц', fontsize=12)
plt.ylabel('count', fontsize=12)
plt.legend(title='Рабочий день', labels=['Выходной/Праздник (0)', 'Рабочий (1)'])
plt.grid(axis='y', alpha=0.3)

# %% [markdown]
# **Ответьте на вопрос:** почему в некоторых месяцах чаще берут велосипеды в будний день, а в некоторые - в выходной.

# %% [markdown]
# Ответ: Начнём с того что ораньжевые столбы это будни. В январе, феврале, декабре количество аренды по будням больше, это может быть связано с тем, что в будни велосипеды используют как транспорт чтобы добраться до работы(не знаю кто они такие, что в снег добираются до работы или до места на велосипеде). А в основном в выходные дни берут чаще велоспиеды, особенно в весенние-осенние месяцы.

# %% [markdown]
# ## Комплексное задание №3. Визуальный анализ данных. Часть 2

# %%
# !pip install seaborn==0.11.0
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Collecting seaborn==0.11.0
#   Downloading seaborn-0.11.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.12/dist-packages (from seaborn==0.11.0) (2.0.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.12/dist-packages (from seaborn==0.11.0) (1.16.3)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.12/dist-packages (from seaborn==0.11.0) (2.2.2)
# Requirement already satisfied: matplotlib>=2.2 in /usr/local/lib/python3.12/dist-packages (from seaborn==0.11.0) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.2->seaborn==0.11.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23->seaborn==0.11.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.23->seaborn==0.11.0) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn==0.11.0) (1.17.0)
# Downloading seaborn-0.11.0-py3-none-any.whl (283 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.1/283.1 kB 17.1 MB/s eta 0:00:00
# Installing collected packages: seaborn
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.13.2
#     Uninstalling seaborn-0.13.2:
#       Successfully uninstalled seaborn-0.13.2
# Successfully installed seaborn-0.11.0

# %%
colab = True # если работаете на своём компьютере, в локальной среде, поставьте False
if colab:
    from google.colab import drive
    drive.mount('/content/drive')

# %% [markdown]
# В этом задании Вам предлагается провести визуальный анализ датасета результатов экзаменов студентов  https://www.kaggle.com/spscientist/students-performance-in-exams.

# %% [markdown]
# Исходные данные загрузите самостоятельно!

# %%
if colab:
    df = pd.read_csv('/content/drive/My Drive/Data/StudentsPerformance.csv')
else:
    df = pd.read_csv("../../data/StudentsPerformance.csv")

df

# %% [markdown]
# ### Ход задания:

# %% [markdown]
# #### 1. Постройте 3 графика, показывающих распределение результатов экзаменов (каждый график на предмет).
#
#
# Графики должны быть в одном ряду и у них должен быть общий заголовок "Результаты экзаменов".
#
# Для результатов каждого экзамена посчитайте медианные значения.

# %% [markdown]
# #### 2. Образование родителей
# Какие уровни образование есть в столбце *'parental level of education'* и сколько строк в датафрейме соответствует каждому уровню?
#
# Постройте график и ответьте на вопрос ниже
#
# Отличаются ли баллы по математике у детей с разным образованием родителей?
# Постройте график, где по оси Х находятся уровни образования родителей, а по У - баллы по математике.

# %% [markdown]
# #### 3. Выведите число студенток, набравших больше 90 баллов по всем предметам.

# %% [markdown]
# #### 4. Сравните баллы у студентов разных полов. Используя agg() выведите минимальное, максимальное и медианное значение

# %% [markdown]
# #### 5. Выясните, влияет ли обед и подготовка к тесту на средний балл студентов разного пола
# ###### (подсказка: используете  [pd.agg()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.agg.html))

# %% [markdown]
# #### 6. Постройте график, показывающий зависимость уровня образования родителей от их расы

# %% [markdown]
# #### 7. Постройте график, показывающий зависимость прохождения подготовительного теста от уровня образования родителей.
#
#
# Кто чаще ходит на курсы: дети, родители которых закончили только старшую школу, или дети, чьи родители получили степень бакалавра\магистра?

# %% [markdown]
# #### 8. Постройте plot.pie, показывающий, сколько людей сдали\не сдали экзамен по математике.
#
# Сдавшим считается человек, набравший 40 баллов.
#
# ###### Подсказка: создайте столбец в датафрейме, который содержит результат сдачи (сдал или не сдал)

# %% [markdown]
# #### 9. Постройте plot.pie, показывающий распределение студентов по оценкам
#
# Оценки студентов выставляются по шкале:<br>
# 0  - 40 marks : grade E<br>
# 41 - 60 marks : grade D<br>
# 60 - 70 marks : grade C<br>
# 70 - 80 marks : grade B<br>
# 80 - 90 marks : grade A<br>
# 90 - 100 marks : grade O<br>
#
# Для этого посчитайте сумму результатов за 3 экзамена и найдите среднее. Оценка выставляется по среднему значению. Если студент не сдал математику(даже если средний балл выше 40), он получает Е

# %% [markdown]
# #### 10. Постройте countplot, показывающий зависимость между итоговой оценкой студентов и его полом. Студенты какого пола получили больше оценок О, А, В
